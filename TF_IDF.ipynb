# %%
from google.colab import drive 
import pandas as pd

# %%
 drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/My Drive/eclipse_platform.csv');

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
sentence=[]
for row in df.iterrows():
  sentence.append(row[1]["Title"])

# %%
sentence[1]#所有的tittle
# Out:
# 'Opening repository resources doesnt honor type (1GE6I1Q)'

# %%
dict1=[];
for x in range(len(sentence)):
    document=sentence[x];
    bagOfWords = document.split(' ');
    dict1.append(bagOfWords);

# %%
words=[];
for i in dict1:
    for j in i:
        words.append(j);

# %%
ba=sentence[1].split(' ')

# %%
from nltk.corpus import stopwords

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopwords.words('english');
en_stops = set(stopwords.words('english'));

# %%
words_without_stopwords=[];
for word in words: 
    if word not in en_stops:
       words_without_stopwords.append(word);
len(words_without_stopwords)
# Out:
# 508191

# %%
unique=set(words_without_stopwords)

# %%
len(unique)
# Out:
# 51531

# %%
numOfWords = dict.fromkeys(unique, 0)
for word in words_without_stopwords:
    numOfWords[word] += 1

# %%
def computeTF(wordDict, bagOfWords):
  # wordDict 字典，每个字段出现次数 bagofwords 检测文本
    tfDict = {}
    bagOfWordsCount = len(bagOfWords)
    for word, count in wordDict.items():
        tfDict[word] = count / float(bagOfWordsCount)
    return tfDict
def computeIDF(documents):
    import math
    N = len(documents)
    
    idfDict = dict.fromkeys(documents[0].keys(), 0)
    for document in documents:
        for word, val in document.items():
            if val > 0:
                idfDict[word] += 1
    
    for word, val in idfDict.items():
        idfDict[word] = math.log(N / float(val))
    return idfDict 
    #idf(w)=总文件数/包含词W的文件数
# def IDF(sentences,unique):#unique为词库，包含了所有出现在sentence中的词汇
#   import math
#   N = len(sentences) #sentence 所有的文本的合集，eg.600000条title的文本内容，sentence[0]为第一条
#   idfdict = dict.fromkeys(unique, 0)
#   for x in sentences:
#     sentence=x.split(' ') #第一条title
#     for y in unique:#词库中的第一个词
#       if y in sentence:#如果title中包含这个词
#         print(sentence)
#         print(y)
#         print("\n")
#         idfdict[y] +=1

#   return idfdict

def computeTFIDF(tfBagOfWords, idfs):
    tfidf = {}
    for word, val in tfBagOfWords.items():
        tfidf[word] = val * idfs[word]
    return tfidf

# %%
tf = computeTF(numOfWords, words_without_stopwords);

# %%
a=IDF(sentence,unique)
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# ['CSS', 'and', 'javascript', 'inserted', 'twice', 'into', 'document', 'from', 'remote', 'server', '(1GHJI2P)']
# server
#
#
# ['request:', 'adjustable', 'font', 'size', '(1GIF0WN)']
# adjustable
#
#
# ['request:', 'adjustable', 'font', 'size', '(1GIF0WN)']
# (1GIF0WN)
#
#
# ['request:', 'adjustable', 'font', 'size', '(1GIF0WN)']
# font
#
#
# ['request:', 'adjustable', 'font', 'size', '(1GIF0WN)']
# request:
#
#
# ['request:', 'adjustable', 'font', 'size', '(1GIF0WN)']
# size
#
#
# ['Netscape', '4.77', 'needs', 'restart', 'to', 'refresh', 'contents', '(1GIGQEM)']
# contents
#
#
# ['Netscape', '4.77', 'needs', 'restart', 'to', 'refresh', 'contents', '(1GIGQEM)']
# refresh
#
#
# ['Netscape', '4.77', 'needs', 'restart', 'to', 'refresh', 'contents', '(1GIGQEM)']
# needs
#
#
# ['Netscape', '4.77', 'needs', 'restart', 'to', 'refresh', 'contents', '(1GIGQEM)']
# Netscape
#
#
# ['Netscape', '4.77', 'needs', 'restart', 'to', 'refresh', 'contents', '(1GIGQEM)']
# ...
